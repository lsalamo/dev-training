# %% [markdown]
# ## What data are we going to play with today?
#
# We are going to play with the data of your *site* from Data platform, more particularly with *Pulse data*.
# We use Athena as medium to connect to it.
#
# ![](pictures/sqlaas.png)
#
#
# [**Reference 1: SQLaaS**](https://confluence.schibsted.io/display/GD/SQLaaS+-+Onboarding+documentation)

# %%
# Required packages

from pyathena import connect
import pandas as pd
import os
from getpass import getpass

# %%
# Some parameters
user = "maria.pelaez@schibsted.com/"
provider ='avitoma'

# %%
access_key = getpass(prompt="Enter your access key to databox: ")
secret_key = getpass(prompt="Enter your secret to databox: ")
# Out:
# Enter your access key to databox:  ····················
# Enter your secret to databox:  ········································

# %%
# Establishing the connection
# TODO: read directly of one path
conn = connect(aws_access_key_id=access_key,
               aws_secret_access_key=secret_key,
               s3_staging_dir="s3://schibsted-spt-common-dev/user-areas/"+ user,
               region_name="eu-west-1")

# %% [markdown]
# ## A. First dataset that we are going to play with: raw data Pulse simplification
#
#
# 1.- **Dataset name to request access:** Insights-FactLayer-Leads
#
# 2.- **Athena (SQLaaS):** {provider}_databox.insights_sessions_fact_layer_7d
#
# 3.- **S3 path** schibsted-spt-common-prod/yellow/pulse-simple/version=1-alpha/*/client=${provider}

# %%
# Doing a simple query
query_events = """
SELECT
  *
FROM
  {}_databox.yellow_pulse_simple_7d
LIMIT 10
"""
df_events = pd.read_sql(query_events.format(provider), conn)

# %%
df_events.head()
# Out:
#                                             category  \
# 0  Servicios > negocios y empleo > Ofertas de empleo
# 1
# 2
# 3
# 4
#
#                                                 name objectlatitude  \
# 0                                   Chofer Colectivo           None
# 1  Clasificados yapo.cl - Avisos Clasificados Gra...           None
# 2                                                              None
# 3  Clasificados yapo.cl - Avisos Clasificados Gra...           None
# 4                                            yapo.cl           None
#
#   objectlongitude                                           objectid  \
# 0            None                    sdrn:yapocl:classified:57750622
# 1            None       sdrn:yapocl:page:https://m.yapo.cl/index.htm
# 2            None  sdrn:yapocl:page:https://tags.tiqcdn.com/utag/...
# 3            None       sdrn:yapocl:page:https://m.yapo.cl/index.htm
# 4            None  sdrn:yapocl:listing:https://m.yapo.cl/araucani...
#
#                                                  url  \
# 0  https://tags.tiqcdn.com/utag/schibsted/yapo-ng...
# 1                        https://m.yapo.cl/index.htm
# 2  https://tags.tiqcdn.com/utag/schibsted/yapo-ng...
# 3                        https://m.yapo.cl/index.htm
# 4                   https://m.yapo.cl/araucania?&o=3
#
#                                                items    objecttype  \
# 0  {"@id":"sdrn:yapocl:job:57750622","@type":"Job...  ClassifiedAd
# 1                                               None          Page
# 2                                               None          Page
# 3                                               None          Page
# 4                                               None       Listing
#
#                                            useragent  \
# 0  Mozilla/5.0 (Linux; Android 7.1.1; SM-J510MN B...
# 1  Mozilla/5.0 (Linux; Android 7.0; SM-P585M Buil...
# 2  Mozilla/5.0 (Linux; Android 7.0; Moto G (5) Bu...
# 3  Mozilla/5.0 (iPhone; CPU iPhone OS 11_4_1 like...
# 4  Mozilla/5.0 (Linux; Android 6.0; BLADE A602 Bu...
#
#                      providerid   ...   intent objectintent devicetype  \
# 0  sdrn:schibsted:client:yapocl   ...     None         None     mobile
# 1  sdrn:schibsted:client:yapocl   ...     None         None     tablet
# 2  sdrn:schibsted:client:yapocl   ...     None         None     mobile
# 3  sdrn:schibsted:client:yapocl   ...     None         None     mobile
# 4  sdrn:schibsted:client:yapocl   ...     None         None     mobile
#
#    version  year month day hour gen  client
# 0  1-alpha  2018    10  25    1   0  yapocl
# 1  1-alpha  2018    10  25    1   0  yapocl
# 2  1-alpha  2018    10  25    1   0  yapocl
# 3  1-alpha  2018    10  25    1   0  yapocl
# 4  1-alpha  2018    10  25    1   0  yapocl
#
# [5 rows x 38 columns]

# %% [markdown]
# ## B. Second dataset that we are going to play with: Simple Pulse Data
#
# 1.- **Dataset name to request access:** Insights-FactLayer-Leads
#
# 2.- **Athena (SQLaaS):** {provider}_databox.insights_leads_fact_layer_90d.
#
# 3.- **S3 path** s3://schibsted-spt-common-prod/yellow/insights/leads/
#
# [More information](https://docs.schibsted.io/data-and-insight/insights-pipelines/10.Data%20Model/fact-layer/#sessions-user-behaviour)

# %%
# Doing a simple query
query_leads = """
SELECT
  *
FROM
  {}_databox.insights_leads_fact_layer_90d
LIMIT 10
"""
df_leads = pd.read_sql(query_leads.format(provider), conn)

# %%
df_leads.head()
# Out:
#                                  leadid          globalleadtype  \
# 0  04d78866-13b5-4481-b22e-b6723655b774  Ad phone number called
# 1  0598e219-0b42-47bb-9643-d6b9c9608526  Ad phone number called
# 2  06378b70-b1bb-4090-8393-2a4d52e1cc35  Ad phone number called
# 3  073b56a9-4d28-4191-baa7-7500ce886c50  Ad phone number called
# 4  07d3d229-26fd-4ea3-a503-5896634a72f5       Ad SMS app opened
#
#                                        environmentid eventtype   eventobject  \
# 0  sdrn:schibsted:environment:4b7859b8-2a82-4efc-...      Call  PhoneContact
# 1  sdrn:schibsted:environment:b398cd81-6738-4b73-...      Call  PhoneContact
# 2  sdrn:schibsted:environment:9fad9935-fb37-43e4-...      Call  PhoneContact
# 3  sdrn:schibsted:environment:0e64f409-21ab-4b42-...      Call  PhoneContact
# 4  sdrn:schibsted:environment:ddf8b939-7a7f-4924-...       SMS  PhoneContact
#
#                    published clientid country  adid adlocalcategory   ...     \
# 0  2018-09-22T13:55:07+00:00  avitoma      ma  NULL            None   ...
# 1  2018-09-22T17:58:21+00:00  avitoma      ma  NULL            None   ...
# 2  2018-09-22T13:08:46+00:00  avitoma      ma  NULL            None   ...
# 3  2018-09-22T13:24:35+00:00  avitoma      ma  NULL            None   ...
# 4  2018-09-22T01:12:30+00:00  avitoma      ma  NULL            None   ...
#
#   devicetype producttype trackertype source version  year month day gen  \
# 0     mobile  AndroidApp     Android  pulse       1  2018     9  22   0
# 1     mobile  AndroidApp     Android  pulse       1  2018     9  22   0
# 2     mobile  AndroidApp     Android  pulse       1  2018     9  22   0
# 3     mobile  AndroidApp     Android  pulse       1  2018     9  22   0
# 4     mobile  AndroidApp     Android  pulse       1  2018     9  22   0
#
#     client
# 0  avitoma
# 1  avitoma
# 2  avitoma
# 3  avitoma
# 4  avitoma
#
# [5 rows x 25 columns]

# %%
df_leads.columns
# Out:
# Index(['leadid', 'globalleadtype', 'environmentid', 'eventtype', 'eventobject',
#        'published', 'clientid', 'country', 'adid', 'adlocalcategory',
#        'adlocalmaincategory', 'adtype', 'adpublishertype', 'adlocation',
#        'adlocalvertical', 'devicetype', 'producttype', 'trackertype', 'source',
#        'version', 'year', 'month', 'day', 'gen', 'client'],
#       dtype='object')
